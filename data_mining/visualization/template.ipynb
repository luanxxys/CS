# %% [markdown]
# # Matlab picture template with Matplotlib and Seaborn

# %% [markdown]
#    > 使用 Titanic 训练数据集

# %% [markdown]
# - ## 折线图

# %%
    import pandas as pd
    import numpy as np
    data = pd.read_csv('titanic_train.csv', header=0)
    data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
    import matplotlib.pyplot as plt
    # %matplotlib inline
    plt.plot()
    plt.show()

# %%
    sex = (data['Sex']=='male').astype('int')
    age = data['Age'].fillna(value=data.Age.mean())
    survived = data['Survived'].astype('int')

# %%
    # 将参数传入
    plt.plot(data['PassengerId'], age)
    # 加标签，标题
    plt.title('test')
    plt.xlabel('PassengerId')
    plt.ylabel('age')
    # 将要画的东西显示出来
    plt.show()

# %% [markdown]
# - ## 子图操作

# %%
    # 指定画图的区间,参数指定画图大小
    fig = plt.figure(figsize=(10,10))
    fig_1 = fig.add_subplot(2,2,1)
    fig_1 = plt.plot(data['PassengerId'], age, c='red')
    fig_1 = plt.plot(data['PassengerId'], survived, c='green')
    # 图例,自动选择最佳位置
    plt.legend(loc='best')
    fig_2 = fig.add_subplot(2,2,4)
    fig_2 = plt.plot(data['PassengerId'], np.random.randint(1,10,891))
    plt.show()

# %% [markdown]
# - ## 条形图

# %%
    # 指定条形图的位置、高度
    # 横坐标范围
    bar_positions = data['PassengerId']
    # fig 定义整体风格
    fig = plt.figure(figsize=(10,5))
    # ax 作图实际上的一个轴，之后在轴上定义内容
    ax1 = fig.add_subplot(1,2,1)
    ax2 = fig.add_subplot(1,2,2)
    # 0.3 宽度可调
    ax1.bar(bar_positions, survived, 0.3)
    # 将图横起来
    ax2.barh(bar_positions, survived, 0.3)
    plt.show()

# %% [markdown]
# - ## 散点图

# %%
    fig = plt.figure(figsize=(10,5))
    ax1 = fig.add_subplot(1,2,1)
    ax2 = fig.add_subplot(1,2,2)
    ax1.scatter(data['PassengerId'], np.random.rand(891))
    ax2.scatter(data['PassengerId'], np.random.rand(891)*.7)
    plt.show()

# %% [markdown]
# - ## 柱形图

# %% [markdown]
# - ## 盒图

# %% [markdown]
# - ## 细节设置
